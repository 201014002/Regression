# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Diameter of pizza
X = [[4], [8], [12], [16], [18]]
# Price
y = [[4], [8], [10], [12], [15]]

# %%
plt.figure()
plt.title('Pizza price vs diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(X, y,'k.')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.show()

# %%
# Algorithm is trained on data (X,y).
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Algorithm predicts price, given a new diameter
diameter = 13
prediction = model.predict([[diameter]])
print('Price prediction: $%.2f' % prediction)
# Out:
# Price prediction: $10.80
